# %%
from src.cmbuilder import *
from pathlib import Path

# %%
ROOT = Path.cwd().resolve().parent.parent
file = ROOT/'src/data/BBinstances.json'

# %%
target_id = '1875daed-73e1-4e74-a392-162961ff754e'
fom(data = file, pol_in = 'TE0', input = 1, id = target_id).phase()
# Out:
#    wavelength pol_in pol_out S11_phase          S21_phase          S31_phase  \
# 0      1500.0    TE0     TE0       NaN  3.141592653589793  3.141592653589793
# 1      1510.0    TE0     TE0       NaN  3.141592653589793  3.141592653589793
# 2      1520.0    TE0     TE0       NaN  3.141592653589793  3.141592653589793
# 3      1530.0    TE0     TE0       NaN  3.141592653589793  3.141592653589793
# 4      1540.0    TE0     TE0       NaN  3.141592653589793  3.141592653589793
# 5      1550.0    TE0     TE0       NaN  3.141592653589793  3.141592653589793
# 6      1560.0    TE0     TE0       NaN  3.141592653589793  3.141592653589793
# 7      1570.0    TE0     TE0       NaN  3.141592653589793  3.141592653589793
# 8      1580.0    TE0     TE0       NaN  3.141592653589793  3.141592653589793
# 9      1590.0    TE0     TE0       NaN  3.141592653589793  3.141592653589793
# 10     1600.0    TE0     TE0       NaN  3.141592653589793  3.141592653589793
# ...
